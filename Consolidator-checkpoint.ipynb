# %%
import pandas as pd
import openpyxl as pyxl
import os

def grab_values(excel_sheet):
    wb = pyxl.load_workbook(excel_sheet, data_only=True)
    ws_list = wb.get_sheet_names()
    named_ranges = [named_range.name for named_range in wb.get_named_ranges()]
    variable_dict = {}
    for named_range in wb.get_named_ranges():
        try:
            sheet_name = named_range.destinations[0][0].title
            cell_name = named_range.destinations[0][1].replace('$','')
            variable_dict[named_range.name] = {}
            variable_dict[named_range.name]['value'] = wb[sheet_name][cell_name].value
            variable_dict[named_range.name]['sheet'] = sheet_name
            variablea_dict[named_range.name]['cell'] = cell_name
        except:
            pass
    return variable_dict
    
def run_program():
    list_of_dicts = {}
    location_dicts = {}
    for sheet in os.listdir(os.getcwd()):
        try:
            location_dicts[sheet] = grab_values("{}\\{}".format(os.getcwd(),sheet)) # windows
            temp_dict = grab_values("{}\\{}".format(os.getcwd(),sheet)) # windows
            # Uncomment above by highlighting the line and ctrl or cmd / removing the leftmost # if on windows and comment mac below
            # location_dicts[sheet] = grab_values(sheet) # mac
            # temp_dict = grab_values(sheet) # mac
            df_dict = {}
            for variable, dictionary in temp_dict.items():
                try:
                    df_dict[variable] = dictionary['value']
                    list_of_dicts[sheet] = df_dict
                except:
                    pass
        except:
            pass 
        print("formated {}".format(sheet))
    df = pd.DataFrame(list_of_dicts).T
    df.to_csv('named_range_database.csv', index_label='workbook')
    return df, location_dicts

def edit_all_files(new_csv, location_dict):
    csv_dict = pd.read_csv(new_csv).T.to_dict()
    for workbook_dict in csv_dict.values():
        wb_filename = workbook_dict['workbook']
        wb = pyxl.load_workbook("{}\\{}".format(os.getcwd(), wb_filename)) # windows
        # wb = pyxl.load_workbook(wb_filename) # mac
        for variable, value in workbook_dict.items(): 
            if variable != "workbook":
                try:
                    sheet_name = location_dict[wb_filename][variable]['sheet']
                    cell_name = location_dict[wb_filename][variable]['cell']
                    wb[sheet_name][cell_name] = value
                except:
                    pass
        wb.save("{}\\{}".format(os.getcwd(), wb_filename)) # windows       
#         wb.save(wb_filename) # mac
        print('Saved {}'.format(wb_filename))

# %%
df, excel_dicts = run_program()
df
# Out:
# formated .ipynb_checkpoints
# formated Canyon Creek.xlsm
# formated Eden Gardens II .xlsm
# formated Everglades Farm Village.xlsm
# formated named_range_database.csv
# formated New.ipynb
# formated Old from car.ipynb
# C:\Anaconda3\lib\site-packages\openpyxl\workbook\names\named_range.py:121: UserWarning: Discarded range with reserved name
#   warnings.warn("Discarded range with reserved name")
#                              N1Acres  \
# Canyon Creek.xlsm                5.9
# Eden Gardens II .xlsm           3.21
# Everglades Farm Village.xlsm     120
#
#                                                                     N1Amenities  \
# Canyon Creek.xlsm             Playground, BBQ area, learning center, communi...
# Eden Gardens II .xlsm         There is an office building (contained in Eden...
# Everglades Farm Village.xlsm  There are additional buildings on the property...
#
#                                                             N1AmenitiesComments  \
# Canyon Creek.xlsm             No deficiencies noted or reported. There are n...
# Eden Gardens II .xlsm                        There are no problematic materials
# Everglades Farm Village.xlsm                     No significant concerns noted.
#
#                              N1AmenitiesCondition N1AmenitiesDeficiencies  \
# Canyon Creek.xlsm                         Average                      No
# Eden Gardens II .xlsm                     Average                      No
# Everglades Farm Village.xlsm              Average                      No
#
#                                                        N1BuildingFacadeComments  \
# Canyon Creek.xlsm             No major signs of wear There are no immediate ...
# Eden Gardens II .xlsm                        There are no problematic materials
# Everglades Farm Village.xlsm                                               None
#
#                              N1BuildingFacadeCondition  \
# Canyon Creek.xlsm                              Average
# Eden Gardens II .xlsm                    Above Average
# Everglades Farm Village.xlsm                      None
#
#                              N1BuildingFacadeDeficiencies  \
# Canyon Creek.xlsm                                      No
# Eden Gardens II .xlsm                                  No
# Everglades Farm Village.xlsm                         None
#
#                                                     N1BuildingFacadeDescription  \
# Canyon Creek.xlsm             Aluminum roof gutters and downspouts were obse...
# Eden Gardens II .xlsm         Aluminum roof gutters and downspouts were obse...
# Everglades Farm Village.xlsm  There were no gutters, soffits, and fascia on ...
#
#                              N1BuildingFacadeLastPainted  \
# Canyon Creek.xlsm                                   None
# Eden Gardens II .xlsm                               None
# Everglades Farm Village.xlsm                        None
#
#                                                     ...                          \
# Canyon Creek.xlsm                                   ...
# Eden Gardens II .xlsm                               ...
# Everglades Farm Village.xlsm                        ...
#
#                              N1perunitperyearuninflated  \
# Canyon Creek.xlsm                               482.421
# Eden Gardens II .xlsm                           492.705
# Everglades Farm Village.xlsm                    464.714
#
#                              N1perunitreservesallyearsinflated  \
# Canyon Creek.xlsm                                      11933.7
# Eden Gardens II .xlsm                                  12207.2
# Everglades Farm Village.xlsm                             11508
#
#                              N1totalreserves10yearsinflated  \
# Canyon Creek.xlsm                                    431099
# Eden Gardens II .xlsm                                244830
# Everglades Farm Village.xlsm                    2.75773e+06
#
#                              N1totalreserves15yearsinflated  \
# Canyon Creek.xlsm                                    592993
# Eden Gardens II .xlsm                                332852
# Everglades Farm Village.xlsm                    3.86634e+06
#
#                              N1totalreserves1yearsinflated  \
# Canyon Creek.xlsm                                   129900
# Eden Gardens II .xlsm                                68191
# Everglades Farm Village.xlsm                        858838
#
#                              N1totalreserves20yearsinflated  \
# Canyon Creek.xlsm                                    811492
# Eden Gardens II .xlsm                                451666
# Everglades Farm Village.xlsm                    5.36275e+06
#
#                              N1totalreserves20yearsuninflated  \
# Canyon Creek.xlsm                                      656092
# Eden Gardens II .xlsm                                  364602
# Everglades Farm Village.xlsm                          4331136
#
#                              N1totalreserves5yearsinflated  \
# Canyon Creek.xlsm                                   230911
# Eden Gardens II .xlsm                               123153
# Everglades Farm Village.xlsm                   1.55106e+06
#
#                              N1unitreservesallyearsuniinflated  \
# Canyon Creek.xlsm                                      9648.41
# Eden Gardens II .xlsm                                  9854.11
# Everglades Farm Village.xlsm                           9294.28
#
#                                                                       SheetList
# Canyon Creek.xlsm             |Summary|Photo Checklist|Lists|V1 Outputs Form...
# Eden Gardens II .xlsm         |Summary|Photo Checklist|Assessment Page 1|Ass...
# Everglades Farm Village.xlsm  |Summary|Photo Checklist|Assessment Page 1|Ass...
#
# [3 rows x 183 columns]

# %%
edit_all_files('named_range_database.csv', excel_dicts)
# Out:
# Saved Canyon Creek.xlsm
# Saved Eden Gardens II .xlsm
# Saved Everglades Farm Village.xlsm
# C:\Anaconda3\lib\site-packages\openpyxl\workbook\names\named_range.py:121: UserWarning: Discarded range with reserved name
#   warnings.warn("Discarded range with reserved name")

# %%
edit_all_files("named_range_database.csv", excel_dicts)
# Out:
# Saved Aspen Grove.xlsm
# Saved ShafterFarms.xlsm
# C:\Anaconda3\lib\site-packages\openpyxl\workbook\names\named_range.py:121: UserWarning: Discarded range with reserved name
#   warnings.warn("Discarded range with reserved name")

# %%
tutorial: tab completion edit_all_files('named_range_database.csv')
